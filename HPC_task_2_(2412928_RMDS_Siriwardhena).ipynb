# 36875.335938,15728.975586,37612.398438,23239.708984
# 94461.828125,7471.035156,44000.578125,65890.562500
# 20352.673828,91630.101562,36401.332031,68140.093750
# 76072.210938,5935.562012,86723.796875,43128.500000
# 62807.429688,16400.185547,21223.230469,33391.535156
# 53291.804688,36523.250000,120708.804688,49010.773438
#
# 4,8
# 60632.812500,101347.445312,122679.578125,78035.328125,7278.660645,15441.746094,114910.664062,23007.634766
# 53054.144531,14693.671875,117469.460938,60525.179688,58694.246094,59903.324219,80877.851562,26867.648438
# 96304.656250,25561.244141,102939.859375,102240.210938,112285.039062,22611.656250,41590.937500,5228.524902
# 43834.886719,74982.476562,58520.332031,80358.132812,72234.578125,107531.109375,98131.585938,9410.694336
#
# 6,6
# 92700.515625,112796.218750,78899.984375,115708.148438,42393.664062,93593.656250
# 109720.906250,102918.843750,28831.203125,46167.531250,60340.000000,55698.851562
# 19015.486328,85901.242188,35182.007812,121255.703125,74729.585938,57793.671875
# 39389.945312,79958.109375,101628.554688,114372.421875,15021.736328,58529.992188
# 63150.300781,122552.843750,33204.882812,72560.992188,84517.992188,7102.660156
# 36550.312500,53761.800781,119898.882812,115450.304688,46013.250000,38835.843750
#
# 6,6
# 32277.458984,18297.992188,114418.460938,78444.992188,78637.992188,46660.613281
# 97460.476562,41082.535156,81842.625000,95259.476562,115812.117188,16179.593750
# 11192.723633,72313.523438,117808.148438,2108.443604,87335.257812,52881.445312
# 65258.746094,86431.398438,86086.328125,14363.036133,47492.687500,93188.992188
# 50913.347656,101254.492188,89631.171875,42906.949219,23811.042969,5010.315918
# 5037.506836,56088.503906,23308.306641,119455.968750,11076.794922,101946.296875
# Out:
# Writing matrix_data.txt

# %%
# %%writefile matrix_file_handler.c
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# #define BUFFER_SIZE 256
#
# struct MatrixSize {
#     int x;
#     int y;
# };
#
# struct Matrix {
#     struct MatrixSize size;
#     double *values;
# };
#
# struct MatrixSize *charArrayIsMatrixSize(char *characters, int size) {
#     struct MatrixSize *mtxSize = (struct MatrixSize *)malloc(sizeof(struct MatrixSize));
#     int splitCount = 0;
#     char temp[BUFFER_SIZE];
#     strcpy(temp, characters);
#
#     char *split = strtok(temp, ",");
#     while (split != NULL) {
#         double parsed = atof(split);
#         if (parsed > 0) {
#             if (splitCount == 0) {
#                 mtxSize->x = parsed;
#             } else if (splitCount == 1) {
#                 mtxSize->y = parsed;
#             } else {
#                 return NULL;
#             }
#             splitCount++;
#         }
#
#         split = strtok(NULL, ",");
#     }
#
#     return mtxSize;
# }
#
# int charArrayIsBlank(char *characters, int size) {
#     return characters[0] == '\n';
# }
#
# double *parseLineOfDoubles(char *lineCharacters, struct MatrixSize mtxSize) {
#     double *lineValues = malloc(sizeof(double) * mtxSize.y);
#     int lineYCount = 0;
#
#     const char splitter[2] = ",";
#     char *split = strtok(lineCharacters, splitter);
#     while (split) {
#         double parsed = atof(split);
#         if (parsed > 0) {
#             lineValues[lineYCount] = parsed;
#             lineYCount += 1;
#         }
#         split = strtok(NULL, splitter);
#     }
#
#     return lineValues;
# }
#
# int getFileMatrixCount(char *fileName) {
#     FILE *filePointer;
#     filePointer = fopen(fileName, "r");
#     if (filePointer == NULL) {
#         printf("Unable to load file '%s'\n", fileName);
#         return 0;
#     }
#
#     int matrixCount = 0;
#     char readBuffer[BUFFER_SIZE];
#     while (fgets(readBuffer, BUFFER_SIZE, filePointer) != NULL) {
#         if (charArrayIsBlank(readBuffer, BUFFER_SIZE) > 0) {
#             matrixCount++;
#         }
#     }
#     matrixCount++;
#
#     fclose(filePointer);
#
#     return matrixCount;
# }
#
# struct Matrix **loadFromFile(char *fileName) {
#     if (!fileName) {
#         printf("Unable to find file '%s'\n", fileName);
#         return NULL;
#     }
#
#     int totalMatrixCount = getFileMatrixCount(fileName);
#
#     FILE *filePointer;
#     filePointer = fopen(fileName, "r");
#     if (filePointer == NULL) {
#         printf("Unable to load file '%s'\n\n", fileName);
#         return NULL;
#     }
#
#     struct Matrix **matrices = malloc(sizeof(struct Matrix) * totalMatrixCount);
#
#     struct MatrixSize *currentMatrixSize = (struct MatrixSize *)malloc(sizeof(struct MatrixSize));
#     currentMatrixSize->x = currentMatrixSize->y = 0;
#
#     double *currentMatrixValues = NULL;
#     int currentMatrixCount = 0;
#     int currentMatrixCurrentLineCount = 0;
#
#     char readBuffer[BUFFER_SIZE];
#     while (fgets(readBuffer, BUFFER_SIZE, filePointer) != NULL) {
#         struct MatrixSize *mtxSize = charArrayIsMatrixSize(readBuffer, BUFFER_SIZE);
#         if (mtxSize != NULL && currentMatrixSize->x == 0 && currentMatrixSize->y == 0) {
#             currentMatrixSize = mtxSize;
#
#         } else if (charArrayIsBlank(readBuffer, BUFFER_SIZE) > 0) {
#
#             struct Matrix *thisMatrix = malloc(sizeof(struct Matrix));
#             thisMatrix->values = currentMatrixValues;
#             thisMatrix->size = *currentMatrixSize;
#
#             matrices[currentMatrixCount] = thisMatrix;
#             currentMatrixCount++;
#             currentMatrixCurrentLineCount = 0;
#             currentMatrixSize->x = currentMatrixSize->y = 0;
#             currentMatrixValues = NULL;
#         } else {
#             if (currentMatrixValues == NULL) {
#                 currentMatrixValues = malloc(sizeof(double) * currentMatrixSize->y);
#             }
#             double *values = parseLineOfDoubles(readBuffer, *currentMatrixSize);
#             for (int i = 0; i < currentMatrixSize->y; i++) {
#                 int index = (currentMatrixCurrentLineCount * currentMatrixSize->y) + i;
#                 currentMatrixValues[index] = values[i];
#             }
#             currentMatrixCurrentLineCount++;
#         }
#     }
#
#     struct Matrix *thisMatrix = malloc(sizeof(struct Matrix));
#     thisMatrix->values = currentMatrixValues;
#     thisMatrix->size = *currentMatrixSize;
#
#     matrices[currentMatrixCount] = thisMatrix;
#
#     currentMatrixCount++;
#
#     fclose(filePointer);
#
#     return matrices;
# }
#
# int saveMatricesToFile(char *filePath, struct Matrix **matrices, int matricesCount) {
#     FILE *saveToFile = fopen(filePath, "w");
#     if (saveToFile == NULL) {
#         printf("Unable to open filePath '%s'. Check it isn't open\n\n", filePath);
#         return 0;
#     }
#
#     for (int i = 0; i < matricesCount; i++) {
#         struct Matrix matrix = *(matrices[i]);
#
#         fprintf(saveToFile, "%d,%d\n", matrix.size.x, matrix.size.y);
#
#         for (int j = 0; j < matrix.size.x; j++) {
#             int rowIndex = (j * matrix.size.y);
#             for (int k = 0; k < matrix.size.y; k++) {
#                 fprintf(saveToFile, "%f", matrix.values[rowIndex + k]);
#                 if (k < matrix.size.y - 1) {
#                     fprintf(saveToFile, ",");
#                 }
#             }
#             fprintf(saveToFile, "\n");
#         }
#         fprintf(saveToFile, "\n");
#     }
#
#     fclose(saveToFile);
#     return 1;
# }
# Out:
# Writing matrix_file_handler.c

# %%
# %%writefile matrix_multipication.c
#
# #include <stdlib.h>
# #include <stdio.h>
# #include <pthread.h>
# #include "matrix_file_handler.c"
#
# struct Matrix **Matrices;
#
# struct ThreadArgs {
#     int threadIndex;
#     int dotProductCount;
#     struct Matrix *resultMatrixInfo;
#     double *matrixAValues;
#     double *matrixBValues;
# };
#
# void printMatrix(double *matrix, int xCount, int yCount);
# void *calculate(void *param);
# int canMultiplyMatrices(struct Matrix a, struct Matrix b);
#
# int main(int argc, char *argv[]) {
#     printf("MATRIX MULTIPLICATION\n\n");
#     char *filePath = "./matrix_data.txt";
#     if (argc > 1) {
#         filePath = argv[1];
#     }
#
#     char *outputFilePath = "./matrix_result20240520.txt";
#     if (argc > 2) {
#         outputFilePath = argv[2];
#     }
#
#     int totalMatrixCount = getFileMatrixCount(filePath);
#     Matrices = loadFromFile(filePath);
#
#     printf("Successfully loaded '%d' matrices from file '%s'\n\n", totalMatrixCount, filePath);
#     struct Matrix **allFinalMatrices = malloc(sizeof(struct Matrix) * totalMatrixCount);
#     int successfulMatrixCount = 0;
#
#     for (int i = 0; i < totalMatrixCount; i += 2) {
#         struct Matrix matrixA = *(Matrices[i]);
#         struct Matrix matrixB = *(Matrices[i + 1]);
#         struct Matrix *resultMatrix = malloc(sizeof(struct Matrix));
#         resultMatrix->size.x = matrixA.size.x;
#         resultMatrix->size.y = matrixB.size.y;
#         resultMatrix->values = malloc(sizeof(double) * resultMatrix->size.x * resultMatrix->size.y);
#
#         int canMultiply = canMultiplyMatrices(matrixA, matrixB);
#         if (canMultiply == 1) {
#             int threadCount = resultMatrix->size.x * resultMatrix->size.y;
#             pthread_t *threadIds = malloc(sizeof(pthread_t) * threadCount);
#
#             for (int i = 0; i < threadCount; i++) {
#                 struct ThreadArgs *args = malloc(sizeof(struct ThreadArgs));
#                 if (args != NULL) {
#                     args->threadIndex = i;
#                     args->dotProductCount = matrixA.size.y;
#                     args->resultMatrixInfo = resultMatrix;
#                     args->matrixAValues = matrixA.values;
#                     args->matrixBValues = matrixB.values;
#                     pthread_create(&threadIds[i], NULL, calculate, args);
#                 }
#             }
#             printf("Created %d threads to create a %d by %d matrix\n\n", threadCount, resultMatrix->size.x, resultMatrix->size.y);
#
#             for (int i = 0; i < threadCount; i++) {
#                 pthread_join(threadIds[i], NULL);
#             }
#
#             printf("Result of Matrix[%d] * Matrix[%d] =\n\n", i, i + 1);
#             printf("Result Matrix:\n");
#             printMatrix(resultMatrix->values, resultMatrix->size.x, resultMatrix->size.y);
#             allFinalMatrices[successfulMatrixCount] = resultMatrix;
#             successfulMatrixCount++;
#         } else {
#             printf("Unable to multiply Matrices[%d] '%dx%d' and  Matrices[%d] '%dx%d'\n\n", i, matrixA.size.x, matrixA.size.y,
#                    i + 1, matrixB.size.x, matrixB.size.y);
#         }
#     }
#
#     int success = saveMatricesToFile(outputFilePath, allFinalMatrices, successfulMatrixCount);
#     if (success == 1) {
#         printf("Successfully saved '%d' matrices into file '%s'\n\n", successfulMatrixCount, outputFilePath);
#     } else {
#         printf("Unable to save to file '%s'\n\n", outputFilePath);
#     }
#     return 0;
# }
#
# void *calculate(void *param) {
#     struct ThreadArgs *args = (struct ThreadArgs *)param;
#     struct MatrixSize resultMatrixSize = args->resultMatrixInfo->size;
#     int index = args->threadIndex;
#     int col = index % resultMatrixSize.x;
#     int row = (index - col) / resultMatrixSize.y;
#
#     if (row >= resultMatrixSize.x || col >= resultMatrixSize.y) {
#         return 0;
#     }
#
#     double total = 0;
#     for (int i = 0; i < args->dotProductCount; i++) {
#         int mtxAThisIndex = (row * (resultMatrixSize.x - 1)) + i;
#         int mtxBThisIndex = (i * resultMatrixSize.y) + col;
#         double aVal = args->matrixAValues[mtxAThisIndex];
#         double bVal = args->matrixBValues[mtxBThisIndex];
#         total += aVal * bVal;
#     }
#     args->resultMatrixInfo->values[args->threadIndex] = total;
#     return NULL;
# }
#
# void printMatrix(double *matrix, int xCount, int yCount) {
#     for (int i = 0; i < xCount; i++) {
#         for (int j = 0; j < yCount; j++) {
#             printf("%f", *(matrix + (i * yCount) + j));
#
#             if (j < yCount - 1) {
#                 printf("    ");
#             }
#         }
#         printf("\n");
#     }
# }
#
# int canMultiplyMatrices(struct Matrix a, struct Matrix b) {
#     if (a.size.y == b.size.x) {
#         return 1;
#     }
#     return 0;
# }
# Out:
# Writing matrix_multipication.c

# %%
# %%shell
#
# gcc matrix_multipication.c -pthread -o output
#
# ./output
# Out:
# MATRIX MULTIPLICATION
#
# Successfully loaded '20' matrices from file './matrix_data.txt'
#
# Created 4 threads to create a 2 by 2 matrix
#
# Result of Matrix[0] * Matrix[1] =
#
# Result Matrix:
# 9947047195.529209    14200596809.529045
# 5382551493.890570    11144399058.714933
# Created 81 threads to create a 9 by 9 matrix
#
# Result of Matrix[2] * Matrix[3] =
#
# Result Matrix:
# 31011369938.519295    35692486797.110977    40653841394.870621    37119512263.544342    42842953929.597488    39459046936.607040    30211185997.392277    46541455110.334343    34304520492.786846
# 32640236631.010986    30685998717.899895    37412104480.121735    32218264575.510696    34393639720.721954    42652589338.320328    28071942299.481888    47801518849.458916    27136608131.766968
# 37583967938.864998    24035568291.892365    32204621134.876968    24965016301.350410    18326142053.251106    26880421196.403160    22311433266.537659    27841082245.337803    29621078243.650002
# ...
